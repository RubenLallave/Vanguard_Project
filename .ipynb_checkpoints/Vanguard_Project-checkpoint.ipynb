# %%
import pandas as pd
import datetime as dt

df_final_demo = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/lessons/refs/heads/main/5_6_eda_inf_stats_tableau/project/files_for_project/df_final_demo.txt')
df_final_demo
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 1        2304905             7.0              94.0      58.0     U        2.0
# 2        1439522             5.0              64.0      32.0     U        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 70604    7993686             4.0              56.0      38.5     U        3.0
# 70605    8981690            12.0             148.0      31.0     M        2.0
# 70606     333913            16.0             198.0      61.5     F        2.0
# 70607    1573142            21.0             255.0      68.0     M        3.0
# 70608    5602139            21.0             254.0      59.5     F        3.0
#
#               bal  calls_6_mnth  logons_6_mnth
# 0        45105.30           6.0            9.0
# 1       110860.30           6.0            9.0
# 2        52467.79           6.0            9.0
# 3        67454.65           3.0            6.0
# 4       103671.75           0.0            3.0
# ...           ...           ...            ...
# 70604  1411062.68           5.0            5.0
# 70605   101867.07           6.0            6.0
# 70606    40745.00           3.0            3.0
# 70607   475114.69           4.0            4.0
# 70608   157498.73           7.0            7.0
#
# [70609 rows x 9 columns]

# %%
df_final_demo.isna().sum()
# Out:
# client_id            0
# clnt_tenure_yr      14
# clnt_tenure_mnth    14
# clnt_age            15
# gendr               14
# num_accts           14
# bal                 14
# calls_6_mnth        14
# logons_6_mnth       14
# dtype: int64

# %%
df_final_demo[df_final_demo.isnull().any(axis=1)]
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 4164     7402828             NaN               NaN       NaN   NaN        NaN
# 8316      355337             NaN               NaN       NaN   NaN        NaN
# 8677     8412164             NaN               NaN       NaN   NaN        NaN
# 9583     4666211             8.0             106.0       NaN     F        2.0
# 13444    2222915             NaN               NaN       NaN   NaN        NaN
# 18066    4876926             NaN               NaN       NaN   NaN        NaN
# 25961    5277910             NaN               NaN       NaN   NaN        NaN
# 28432    7616759             NaN               NaN       NaN   NaN        NaN
# 35323    8191345             NaN               NaN       NaN   NaN        NaN
# 43518    1227228             NaN               NaN       NaN   NaN        NaN
# 46076    8611797             NaN               NaN       NaN   NaN        NaN
# 47189    5144725             NaN               NaN       NaN   NaN        NaN
# 49846    1037867             NaN               NaN       NaN   NaN        NaN
# 63701    1618749             NaN               NaN       NaN   NaN        NaN
# 66219    6021001             NaN               NaN       NaN   NaN        NaN
#
#             bal  calls_6_mnth  logons_6_mnth
# 4164        NaN           NaN            NaN
# 8316        NaN           NaN            NaN
# 8677        NaN           NaN            NaN
# 9583   42550.55           4.0            7.0
# 13444       NaN           NaN            NaN
# 18066       NaN           NaN            NaN
# 25961       NaN           NaN            NaN
# 28432       NaN           NaN            NaN
# 35323       NaN           NaN            NaN
# 43518       NaN           NaN            NaN
# 46076       NaN           NaN            NaN
# 47189       NaN           NaN            NaN
# 49846       NaN           NaN            NaN
# 63701       NaN           NaN            NaN
# 66219       NaN           NaN            NaN

# %%
# Drop all the 15 rows with null values
#df_final_demo = df_final_demo.dropna()
df_final_demo = df_final_demo.dropna(subset=["clnt_tenure_yr"]) #if required the row 9583  !!!!!!!!!!!!!!!!!

df_final_demo[df_final_demo.isnull().any(axis=1)]
# Out:
#       client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 9583    4666211             8.0             106.0       NaN     F        2.0
#
#            bal  calls_6_mnth  logons_6_mnth
# 9583  42550.55           4.0            7.0

# %%
df_final_demo.dtypes
# Out:
# client_id             int64
# clnt_tenure_yr      float64
# clnt_tenure_mnth    float64
# clnt_age            float64
# gendr                object
# num_accts           float64
# bal                 float64
# calls_6_mnth        float64
# logons_6_mnth       float64
# dtype: object

# %%
# Change floats to integers???

df_final_demo = df_final_demo.astype({
    "clnt_tenure_yr": "int",
    "clnt_tenure_mnth": "int",
    #"clnt_age": "int", not possible with null values
    "gendr": "object",
    "num_accts": "int",
    "calls_6_mnth": "int",
    "logons_6_mnth": "int"
})
df_final_demo
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976               6                73      60.5     U          2
# 1        2304905               7                94      58.0     U          2
# 2        1439522               5                64      32.0     U          2
# 3        1562045              16               198      49.0     M          2
# 4        5126305              12               145      33.0     F          2
# ...          ...             ...               ...       ...   ...        ...
# 70604    7993686               4                56      38.5     U          3
# 70605    8981690              12               148      31.0     M          2
# 70606     333913              16               198      61.5     F          2
# 70607    1573142              21               255      68.0     M          3
# 70608    5602139              21               254      59.5     F          3
#
#               bal  calls_6_mnth  logons_6_mnth
# 0        45105.30             6              9
# 1       110860.30             6              9
# 2        52467.79             6              9
# 3        67454.65             3              6
# 4       103671.75             0              3
# ...           ...           ...            ...
# 70604  1411062.68             5              5
# 70605   101867.07             6              6
# 70606    40745.00             3              3
# 70607   475114.69             4              4
# 70608   157498.73             7              7
#
# [70595 rows x 9 columns]

# %%
# Update with more understandale names
df_final_demo.columns = ["client_id", "client_tenure_years", "client_tenure_months", "client_age", "gender", "num_accounts", "balance", "calls_last_6_months", "logins_last_6_months"]
df_final_demo
# Out:
#        client_id  client_tenure_years  client_tenure_months  client_age  \
# 0         836976                    6                    73        60.5
# 1        2304905                    7                    94        58.0
# 2        1439522                    5                    64        32.0
# 3        1562045                   16                   198        49.0
# 4        5126305                   12                   145        33.0
# ...          ...                  ...                   ...         ...
# 70604    7993686                    4                    56        38.5
# 70605    8981690                   12                   148        31.0
# 70606     333913                   16                   198        61.5
# 70607    1573142                   21                   255        68.0
# 70608    5602139                   21                   254        59.5
#
#       gender  num_accounts     balance  calls_last_6_months  \
# 0          U             2    45105.30                    6
# 1          U             2   110860.30                    6
# 2          U             2    52467.79                    6
# 3          M             2    67454.65                    3
# 4          F             2   103671.75                    0
# ...      ...           ...         ...                  ...
# 70604      U             3  1411062.68                    5
# 70605      M             2   101867.07                    6
# 70606      F             2    40745.00                    3
# 70607      M             3   475114.69                    4
# 70608      F             3   157498.73                    7
#
#        logins_last_6_months
# 0                         9
# 1                         9
# 2                         9
# 3                         6
# 4                         3
# ...                     ...
# 70604                     5
# 70605                     6
# 70606                     3
# 70607                     4
# 70608                     7
#
# [70595 rows x 9 columns]

# %%
print(df_final_demo.columns)
# Out:
# Index(['client_id', 'client_tenure_years', 'client_tenure_months',
#        'client_age', 'gender', 'num_accounts', 'balance',
#        'calls_last_6_months', 'logins_last_6_months'],
#       dtype='object')

# %%
def categorize_age(age):
    if age > 60:
        return "Above 60"
    elif 30 < age <= 60:
        return "Between 30 and 60"
    else:
        return "Below 30"

age_counts = df_final_demo.groupby(df_final_demo["client_age"].apply(categorize_age))["client_id"].count()
print(age_counts)

# PENDING CREATE NEW COLUMN WITH THIS age_counts DATA!!!
# Out:
# client_age
# Above 60             15501
# Below 30             14025
# Between 30 and 60    41069
# Name: client_id, dtype: int64

# %%
age_counts.plot(kind="bar", color=["blue", "orange", "green"])
# Out:
# <Axes: xlabel='client_age'>

# %%
df_final_demo["client_tenure_years"].unique()
# Out:
# array([ 6,  7,  5, 16, 12, 30, 15,  8,  4,  3, 10, 11, 13, 14, 19, 18, 25,
#        23, 21, 17,  9, 27, 24, 20, 28, 22, 29, 46, 26, 32, 33, 35,  2, 38,
#        31, 48, 34, 36, 51, 47, 49, 37, 39, 40, 55, 42, 44, 43, 50, 54, 41,
#        45, 52, 62])

# %%
def categorize_tenure_years(tenure):
    if tenure > 20:
        return "Above 20"
    elif 10 < tenure <= 20:
        return "Between 10 and 20"
    else:
        return "Below 10"

tenure_counts = df_final_demo.groupby(df_final_demo["client_tenure_years"].apply(categorize_tenure_years))["client_tenure_years"].count()
print(tenure_counts)

# PENDING CREATE NEW COLUMN WITH THIS tenure_counts DATA!!!
# Out:
# client_tenure_years
# Above 20              9805
# Below 10             34396
# Between 10 and 20    26394
# Name: client_tenure_years, dtype: int64

# %%
tenure_counts.plot(kind="bar", color=["blue", "orange", "green"])
# Out:
# <Axes: xlabel='client_tenure_years'>

# %%
df_final_web_1 = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/lessons/refs/heads/main/5_6_eda_inf_stats_tableau/project/files_for_project/df_final_web_data_pt_1.txt')
df_final_web_1
# Out:
#         client_id             visitor_id                      visit_id  \
# 0         9988021   580560515_7732621733  781255054_21935453173_531117
# 1         9988021   580560515_7732621733  781255054_21935453173_531117
# 2         9988021   580560515_7732621733  781255054_21935453173_531117
# 3         9988021   580560515_7732621733  781255054_21935453173_531117
# 4         9988021   580560515_7732621733  781255054_21935453173_531117
# ...           ...                    ...                           ...
# 343136    2443347  465784886_73090545671  136329900_10529659391_316129
# 343137    2443347  465784886_73090545671  136329900_10529659391_316129
# 343138    2443347  465784886_73090545671  136329900_10529659391_316129
# 343139    2443347  465784886_73090545671  136329900_10529659391_316129
# 343140    2443347  465784886_73090545671  136329900_10529659391_316129
#
#        process_step            date_time
# 0            step_3  2017-04-17 15:27:07
# 1            step_2  2017-04-17 15:26:51
# 2            step_3  2017-04-17 15:19:22
# 3            step_2  2017-04-17 15:19:13
# 4            step_3  2017-04-17 15:18:04
# ...             ...                  ...
# 343136      confirm  2017-03-31 15:15:46
# 343137       step_3  2017-03-31 15:14:53
# 343138       step_2  2017-03-31 15:12:08
# 343139       step_1  2017-03-31 15:11:37
# 343140        start  2017-03-31 15:10:47
#
# [343141 rows x 5 columns]

# %%
df_final_web_1 = df_final_web_1.drop_duplicates()

# %%
df_final_web_1[df_final_web_1['client_id'].duplicated()]
# Out:
#         client_id             visitor_id                      visit_id  \
# 1         9988021   580560515_7732621733  781255054_21935453173_531117
# 2         9988021   580560515_7732621733  781255054_21935453173_531117
# 3         9988021   580560515_7732621733  781255054_21935453173_531117
# 4         9988021   580560515_7732621733  781255054_21935453173_531117
# 5         9988021   580560515_7732621733  781255054_21935453173_531117
# ...           ...                    ...                           ...
# 343136    2443347  465784886_73090545671  136329900_10529659391_316129
# 343137    2443347  465784886_73090545671  136329900_10529659391_316129
# 343138    2443347  465784886_73090545671  136329900_10529659391_316129
# 343139    2443347  465784886_73090545671  136329900_10529659391_316129
# 343140    2443347  465784886_73090545671  136329900_10529659391_316129
#
#        process_step            date_time
# 1            step_2  2017-04-17 15:26:51
# 2            step_3  2017-04-17 15:19:22
# 3            step_2  2017-04-17 15:19:13
# 4            step_3  2017-04-17 15:18:04
# 5            step_2  2017-04-17 15:17:15
# ...             ...                  ...
# 343136      confirm  2017-03-31 15:15:46
# 343137       step_3  2017-03-31 15:14:53
# 343138       step_2  2017-03-31 15:12:08
# 343139       step_1  2017-03-31 15:11:37
# 343140        start  2017-03-31 15:10:47
#
# [282655 rows x 5 columns]

# %%
df_final_web_1['date_time'] = pd.to_datetime(df_final_web_1['date_time'])
# Out:
# C:\Users\abarr\AppData\Local\Temp\ipykernel_19956\1485273086.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final_web_1['date_time'] = pd.to_datetime(df_final_web_1['date_time'])

# %%
df_final_web_1.dtypes
# Out:
# client_id                int64
# visitor_id              object
# visit_id                object
# process_step            object
# date_time       datetime64[ns]
# dtype: object

# %%
df_final_web_2 = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/lessons/refs/heads/main/5_6_eda_inf_stats_tableau/project/files_for_project/df_final_web_data_pt_2.txt')
df_final_web_2
# Out:
#         client_id             visitor_id                      visit_id  \
# 0          763412  601952081_10457207388  397475557_40440946728_419634
# 1         6019349  442094451_91531546617  154620534_35331068705_522317
# 2         6019349  442094451_91531546617  154620534_35331068705_522317
# 3         6019349  442094451_91531546617  154620534_35331068705_522317
# 4         6019349  442094451_91531546617  154620534_35331068705_522317
# ...           ...                    ...                           ...
# 412259    9668240   388766751_9038881013   922267647_3096648104_968866
# 412260    9668240   388766751_9038881013   922267647_3096648104_968866
# 412261    9668240   388766751_9038881013   922267647_3096648104_968866
# 412262    9668240   388766751_9038881013   922267647_3096648104_968866
# 412263     674799  947159805_81558194550   86152093_47511127657_716022
#
#        process_step            date_time
# 0           confirm  2017-06-06 08:56:00
# 1           confirm  2017-06-01 11:59:27
# 2            step_3  2017-06-01 11:58:48
# 3            step_2  2017-06-01 11:58:08
# 4            step_1  2017-06-01 11:57:58
# ...             ...                  ...
# 412259        start  2017-05-24 18:46:10
# 412260        start  2017-05-24 18:45:29
# 412261       step_1  2017-05-24 18:44:51
# 412262        start  2017-05-24 18:44:34
# 412263        start  2017-06-03 12:17:09
#
# [412264 rows x 5 columns]

# %%
df_final_experiment = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/lessons/refs/heads/main/5_6_eda_inf_stats_tableau/project/files_for_project/df_final_experiment_clients.txt')
df_final_experiment
# Out:
#        client_id Variation
# 0        9988021      Test
# 1        8320017      Test
# 2        4033851   Control
# 3        1982004      Test
# 4        9294070   Control
# ...          ...       ...
# 70604    2443347       NaN
# 70605    8788427       NaN
# 70606     266828       NaN
# 70607    1266421       NaN
# 70608    9895983       NaN
#
# [70609 rows x 2 columns]

# %%
df_final_experiment.isna().sum()
# Out:
# client_id        0
# Variation    20109
# dtype: int64

# %%
df_final_experiment["Variation"].value_counts()
# Out:
# Variation
# Test       26968
# Control    23532
# Name: count, dtype: int64

# %%
df_final_experiment["client_id"].duplicated().any()
# Out:
# np.False_

# %%
df_final_experiment.dtypes
# Out:
# client_id     int64
# Variation    object
# dtype: object

# %%
df_final_demo_experiment = df_final_demo.merge(df_final_experiment, on = 'client_id', how='left')
df_final_demo_experiment
# Out:
#        client_id  client_tenure_years  client_tenure_months  client_age  \
# 0         836976                    6                    73        60.5
# 1        2304905                    7                    94        58.0
# 2        1439522                    5                    64        32.0
# 3        1562045                   16                   198        49.0
# 4        5126305                   12                   145        33.0
# ...          ...                  ...                   ...         ...
# 70590    7993686                    4                    56        38.5
# 70591    8981690                   12                   148        31.0
# 70592     333913                   16                   198        61.5
# 70593    1573142                   21                   255        68.0
# 70594    5602139                   21                   254        59.5
#
#       gender  num_accounts     balance  calls_last_6_months  \
# 0          U             2    45105.30                    6
# 1          U             2   110860.30                    6
# 2          U             2    52467.79                    6
# 3          M             2    67454.65                    3
# 4          F             2   103671.75                    0
# ...      ...           ...         ...                  ...
# 70590      U             3  1411062.68                    5
# 70591      M             2   101867.07                    6
# 70592      F             2    40745.00                    3
# 70593      M             3   475114.69                    4
# 70594      F             3   157498.73                    7
#
#        logins_last_6_months Variation
# 0                         9      Test
# 1                         9   Control
# 2                         9      Test
# 3                         6      Test
# 4                         3   Control
# ...                     ...       ...
# 70590                     5       NaN
# 70591                     6       NaN
# 70592                     3       NaN
# 70593                     4       NaN
# 70594                     7       NaN
#
# [70595 rows x 10 columns]

# %%
df_final_demo_experiment.dropna(subset=["Variation"], inplace=True) 
#dropping null values in Variation because it will not be used in the analysis

# %%
df_final_demo_experiment
# Out:
#        client_id  client_tenure_years  client_tenure_months  client_age  \
# 0         836976                    6                    73        60.5
# 1        2304905                    7                    94        58.0
# 2        1439522                    5                    64        32.0
# 3        1562045                   16                   198        49.0
# 4        5126305                   12                   145        33.0
# ...          ...                  ...                   ...         ...
# 50483    1780858                   21                   262        68.5
# 50484    6967120                   21                   260        68.5
# 50485    5826160                   20                   249        56.5
# 50486    8739285                   19                   229        69.5
# 50487    7468138                   18                   222        61.0
#
#       gender  num_accounts     balance  calls_last_6_months  \
# 0          U             2    45105.30                    6
# 1          U             2   110860.30                    6
# 2          U             2    52467.79                    6
# 3          M             2    67454.65                    3
# 4          F             2   103671.75                    0
# ...      ...           ...         ...                  ...
# 50483      M             3   372100.59                    6
# 50484      M             3  4279873.38                    6
# 50485      F             2    44837.16                    2
# 50486      F             2    44994.24                    1
# 50487      F             3   209278.15                    0
#
#        logins_last_6_months Variation
# 0                         9      Test
# 1                         9   Control
# 2                         9      Test
# 3                         6      Test
# 4                         3   Control
# ...                     ...       ...
# 50483                     9      Test
# 50484                     9   Control
# 50485                     5      Test
# 50486                     4      Test
# 50487                     3      Test
#
# [50488 rows x 10 columns]

# %%
df_final_web_2.isnull().sum() # no null values
# Out:
# client_id       0
# visitor_id      0
# visit_id        0
# process_step    0
# date_time       0
# dtype: int64

# %%
df_final_web_2.duplicated().value_counts() # there are 8669 duplicated rows
# Out:
# False    403595
# True       8669
# Name: count, dtype: int64

# %%
df_final_web_2.drop_duplicates(inplace = True) #drop the duplicated values
df_final_web_2.duplicated().value_counts() # confirming no duplicated values
# Out:
# False    403595
# Name: count, dtype: int64

# %%
df_final_web_2.nunique()
# Out:
# client_id        67430
# visitor_id       71042
# visit_id         82841
# process_step         5
# date_time       346697
# dtype: int64

# %%
#merge df_final_web_2 with df_final_web1
final_web = pd.concat([df_final_web_1, df_final_web_2])
final_web.shape
# Out:
# (744641, 5)

# %%
final_web.duplicated().sum()
# Out:
# np.int64(0)

# %%
final_web['datetime']= pd.to_datetime(final_web['date_time'])
final_web.dtypes
# Out:
# client_id                int64
# visitor_id              object
# visit_id                object
# process_step            object
# date_time               object
# datetime        datetime64[ns]
# dtype: object

# %%
#calculate completion rate
val = final_web['process_step'].value_counts() 
display(val)

total_completion_rate = round(val['confirm']/val['start']*100,1)
total_completion_rate
# Out:
# process_step
# start      234999
# step_1     162797
# step_2     132750
# step_3     111589
# confirm    102506
# Name: count, dtype: int64
# np.float64(43.6)

# %%
#calculate completion rate by variation
final_web.groupby(['Variation','process_step']).size().unstack()

# %%
#Drop column datetime
final_web.drop(columns = ['date_time'], inplace = True)

# %%
final_web
# Out:
#         client_id             visitor_id                      visit_id  \
# 0         9988021   580560515_7732621733  781255054_21935453173_531117
# 1         9988021   580560515_7732621733  781255054_21935453173_531117
# 2         9988021   580560515_7732621733  781255054_21935453173_531117
# 3         9988021   580560515_7732621733  781255054_21935453173_531117
# 4         9988021   580560515_7732621733  781255054_21935453173_531117
# ...           ...                    ...                           ...
# 412259    9668240   388766751_9038881013   922267647_3096648104_968866
# 412260    9668240   388766751_9038881013   922267647_3096648104_968866
# 412261    9668240   388766751_9038881013   922267647_3096648104_968866
# 412262    9668240   388766751_9038881013   922267647_3096648104_968866
# 412263     674799  947159805_81558194550   86152093_47511127657_716022
#
#        process_step            datetime
# 0            step_3 2017-04-17 15:27:07
# 1            step_2 2017-04-17 15:26:51
# 2            step_3 2017-04-17 15:19:22
# 3            step_2 2017-04-17 15:19:13
# 4            step_3 2017-04-17 15:18:04
# ...             ...                 ...
# 412259        start 2017-05-24 18:46:10
# 412260        start 2017-05-24 18:45:29
# 412261       step_1 2017-05-24 18:44:51
# 412262        start 2017-05-24 18:44:34
# 412263        start 2017-06-03 12:17:09
#
# [744641 rows x 5 columns]

# %%
# calculate error rate - this means that the user in a certain visit had to come a step back in the process


final_web.drop(columns= "error", inplace = True)

# %%
final_web["process_step"].astype(category = ["start" < "step_1" < "step_2" < "step_3" < "confirm"])
final_web["count_step"] = if final_web["process_step"] == "start"  0:

# %%
# count repeated steps per visit_id
final_web.loc[final_web['visit_id'] == '781255054_21935453173_531117'].value_counts(['process_step'])
# Out:
# process_step
# step_3          3
# step_2          3
# step_1          1
# start           1
# Name: count, dtype: int64

# %%
#sort the values for this visit by datetime
final_web.loc[final_web['visit_id'] == '781255054_21935453173_531117'].sort_values(by = 'datetime')
# Out:
#    client_id            visitor_id                      visit_id process_step  \
# 7    9988021  580560515_7732621733  781255054_21935453173_531117        start
# 6    9988021  580560515_7732621733  781255054_21935453173_531117       step_1
# 5    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 4    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 3    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 2    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 1    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 0    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
#
#              datetime
# 7 2017-04-17 15:16:22
# 6 2017-04-17 15:17:01
# 5 2017-04-17 15:17:15
# 4 2017-04-17 15:18:04
# 3 2017-04-17 15:19:13
# 2 2017-04-17 15:19:22
# 1 2017-04-17 15:26:51
# 0 2017-04-17 15:27:07

# %%
final_web["time_spent"] = final_web["datetime"].diff

# %%
final_web["datetime"].iloc[2]-final_web["datetime"].iloc[1]
# Out:
# Timedelta('-1 days +23:52:31')

# %%
#final_web = final_web.sort_values(["visit_id", "datetime"])
test = final_web.groupby(["visit_id"])['process_step'].value_counts()
test
# Out:
# visit_id                      process_step
# 100012776_37918976071_457913  confirm         2
# 1000165_4190026492_760066     confirm         1
#                               start           1
#                               step_1          1
#                               step_2          1
#                                              ..
# 999992932_41666455053_671149  confirm         2
#                               start           1
#                               step_1          1
#                               step_2          1
#                               step_3          1
# Name: count, Length: 553417, dtype: int64

# %%
# verify if there is any value > 1 in the grouped tables

# %%
final_web = final_web.sort_values(["visit_id", "datetime"])
final_web['time_spent']= final_web.groupby(['client_id', 'visit_id'])['datetime'].diff().dt.total_seconds()
avg_time_each_step = final_web.groupby(['process_step'])['time_spent'].mean()
avg_time_each_step
# Out:
# process_step
# confirm    131.109420
# start      158.645364
# step_1      39.576880
# step_2      45.911035
# step_3     100.003280
# Name: time_spent, dtype: float64
